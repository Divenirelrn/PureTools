# %% [markdown]
# git介绍
#
# git:分布式版本控制工具
#
# git结构：
#     本地库
#          |  git commit
#     缓存区
#          |  git add
#     工作区
#
# 代码托管中心：
#     局域网：gitlab
#     外网：github, gitlee
#
# 本地库与远程库交互：
#     ![git.jpg](attachment:git.jpg)
